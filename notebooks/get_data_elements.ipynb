# %%
import glob
import os
import pandas as pd
import utils

# %%
# NIH Data Hub path (if used)
data_path = "../../phs*/"  

# Local data path
data_path = "../data/phs*/"  

# Results directory
result_dir = "../../results"  # or RESULT_DIR if truly constant

# RADx-rad data elements
tier1_harmonized_dict = "https://github.com/radxrad/common-data-elements/raw/refs/heads/main/cdes/RADx-rad_tier1_dict_2025-03-19.csv"
tier2_harmonized_dict = "https://github.com/radxrad/common-data-elements/raw/refs/heads/main/cdes/RADx-rad_tier2_dict_2025-03-19.csv"

# %%
def get_data_elements(dict_file_path):
    df_list = []

    for directory in glob.glob(dict_file_path):
        for dict_file in glob.glob(os.path.join(directory, "*DICT_origcopy.csv")):
            # Collect dictionary data
            df = pd.read_csv(dict_file, dtype=str, keep_default_na=False)

            # Collect metadata
            meta_file = dict_file.replace("_DICT_origcopy.csv", "_META_origcopy.json")
            subproject, phs_identifier, project_num, _ = utils.extract_fields_from_metadata(meta_file)
            df["subproject"] = subproject
            df["phs_id"] = phs_identifier
            df["study_id"] = os.path.basename(os.path.dirname(meta_file))
            df["project_num"] = project_num
            df["radx_id"] = utils.extract_radx_id(meta_file)
            df["filename" ] = os.path.basename(dict_file)

            df_list.append(df)

    data = pd.concat(df_list)
    data.drop_duplicates(inplace=True)
    data = utils.assign_data_element_tier(data, tier1_harmonized_dict, tier2_harmonized_dict)
    
    return data

# %%
dicts = get_data_elements(data_path)
dicts.head()
# Out:
#                     Id                                              Label  \
# 0             study_id         RADx-rad Study ID; Subject ID; Datavent ID
# 1            cohort_id                  Identifier for groups of patients
# 2     study_population  The subjects/patients (and specimen types) inc...
# 3          protocol_id   Unique name or identifier for biosensor protocol
# 4  technology_platform         Abbreviation or short label for technology
#
#            Examples               Section Cardinality  \
# 0                                Identity      single
# 1                                Clinical    multiple
# 2                    Clinical Performance    multiple
# 3  ddPCR_SARS-CoV-2   Technology Metadata      single
# 4             ddPCR   Technology Metadata      single
#
#                                            Terms Datatype Unit Enumeration  \
# 0                                   NCIT:C164337   string
# 1                                   NCIT:C183331   string
# 2                                    NCIT:C70833   string
# 3  http://edamontology.org/data:2531 NCIT:C25364   string
# 4                                    NCIT:C45378   string
#
#   Notes                    MissingValueCodes            Provenance  \
# 0        "-9960"=[Not Entered By Originator]  RADx-rad Minimum CDE
# 1        "-9960"=[Not Entered By Originator]          RADx-rad DCC
# 2        "-9960"=[Not Entered By Originator]          RADx-rad DCC
# 3        "-9960"=[Not Entered By Originator]          RADx-rad DCC
# 4        "-9960"=[Not Entered By Originator]          RADx-rad DCC
#
#                                              SeeAlso subproject  \
# 0                                                       Exosome
# 1                                                       Exosome
# 2  https://www.fda.gov/files/medical%20devices/pu...    Exosome
# 3                                                       Exosome
# 4                                                       Exosome
#
#             phs_id   study_id      project_num         radx_id  \
# 0  phs002544.v1.p1  phs002544  1U18TR003778-01  rad_018_778-01
# 1  phs002544.v1.p1  phs002544  1U18TR003778-01  rad_018_778-01
# 2  phs002544.v1.p1  phs002544  1U18TR003778-01  rad_018_778-01
# 3  phs002544.v1.p1  phs002544  1U18TR003778-01  rad_018_778-01
# 4  phs002544.v1.p1  phs002544  1U18TR003778-01  rad_018_778-01
#
#                                             filename   tier
# 0  rad_018_778-01_NAB_CLINICALSAMPLERESULTS_DICT_...  tier1
# 1  rad_018_778-01_NAB_CLINICALSAMPLERESULTS_DICT_...  tier2
# 2  rad_018_778-01_NAB_CLINICALSAMPLERESULTS_DICT_...  tier2
# 3  rad_018_778-01_NAB_CLINICALSAMPLERESULTS_DICT_...  tier2
# 4  rad_018_778-01_NAB_CLINICALSAMPLERESULTS_DICT_...  tier2

# %%
print(f"Number of studies              : {dicts['study_id'].nunique()}")
print(f"Number of data elements        : {dicts.shape[0]}")
print(f"Number of unique data elements : {dicts['Id'].nunique()}")
dicts.head()
# Out:
# Number of studies              : 1
# Number of data elements        : 723
# Number of unique data elements : 272
#                     Id                                              Label  \
# 0             study_id         RADx-rad Study ID; Subject ID; Datavent ID
# 1            cohort_id                  Identifier for groups of patients
# 2     study_population  The subjects/patients (and specimen types) inc...
# 3          protocol_id   Unique name or identifier for biosensor protocol
# 4  technology_platform         Abbreviation or short label for technology
#
#            Examples               Section Cardinality  \
# 0                                Identity      single
# 1                                Clinical    multiple
# 2                    Clinical Performance    multiple
# 3  ddPCR_SARS-CoV-2   Technology Metadata      single
# 4             ddPCR   Technology Metadata      single
#
#                                            Terms Datatype Unit Enumeration  \
# 0                                   NCIT:C164337   string
# 1                                   NCIT:C183331   string
# 2                                    NCIT:C70833   string
# 3  http://edamontology.org/data:2531 NCIT:C25364   string
# 4                                    NCIT:C45378   string
#
#   Notes                    MissingValueCodes            Provenance  \
# 0        "-9960"=[Not Entered By Originator]  RADx-rad Minimum CDE
# 1        "-9960"=[Not Entered By Originator]          RADx-rad DCC
# 2        "-9960"=[Not Entered By Originator]          RADx-rad DCC
# 3        "-9960"=[Not Entered By Originator]          RADx-rad DCC
# 4        "-9960"=[Not Entered By Originator]          RADx-rad DCC
#
#                                              SeeAlso subproject  \
# 0                                                       Exosome
# 1                                                       Exosome
# 2  https://www.fda.gov/files/medical%20devices/pu...    Exosome
# 3                                                       Exosome
# 4                                                       Exosome
#
#             phs_id   study_id      project_num         radx_id  \
# 0  phs002544.v1.p1  phs002544  1U18TR003778-01  rad_018_778-01
# 1  phs002544.v1.p1  phs002544  1U18TR003778-01  rad_018_778-01
# 2  phs002544.v1.p1  phs002544  1U18TR003778-01  rad_018_778-01
# 3  phs002544.v1.p1  phs002544  1U18TR003778-01  rad_018_778-01
# 4  phs002544.v1.p1  phs002544  1U18TR003778-01  rad_018_778-01
#
#                                             filename   tier
# 0  rad_018_778-01_NAB_CLINICALSAMPLERESULTS_DICT_...  tier1
# 1  rad_018_778-01_NAB_CLINICALSAMPLERESULTS_DICT_...  tier2
# 2  rad_018_778-01_NAB_CLINICALSAMPLERESULTS_DICT_...  tier2
# 3  rad_018_778-01_NAB_CLINICALSAMPLERESULTS_DICT_...  tier2
# 4  rad_018_778-01_NAB_CLINICALSAMPLERESULTS_DICT_...  tier2

# %%
os.makedirs(result_dir, exist_ok=True)

# %%
dicts.to_csv(os.path.join(result_dir, "data_elements.csv"), index=False)
